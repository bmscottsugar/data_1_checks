# %%
import pandas as pd

autism_prevalence_studies = pd.read_csv (r'C:\Users\Brandon\Desktop\Data 1 Checks repo\Assets\autism_prevalence_studies.csv')
print (austism_prevalence_studies)
# Out:
#                          Author  \
# 0                        Lotter
# 1                      Treffert
# 2                         Brask
# 3                  Wing, et al.
# 4                  Wing, et al.
# ..                          ...
# 195  Safer-Lichtenstein, et al.
# 196               Bosch, et al.
# 197              Brooks, et al.
# 198                Yuan, et al.
# 199             Morales-Hidalgo
#
#                                                  Title  Year Published  \
# 0    Epidemiology of Autistic Conditions in Young C...            1966
# 1                     Epidemiology of infantile Autism            1970
# 2    A Prevalence investigation of Childhood Psychoses            1972
# 3    The prevalence of early childhood autism: comp...            1976
# 4    Severe impairments of social interaction and a...            1979
# ..                                                 ...             ...
# 195  School-Based Autism Rates by State: An Analysi...            2020
# ...

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
austism_prevalence_studies
# Out:
#                          Author  \
# 0                        Lotter
# 1                      Treffert
# 2                         Brask
# 3                  Wing, et al.
# 4                  Wing, et al.
# ..                          ...
# 195  Safer-Lichtenstein, et al.
# 196               Bosch, et al.
# 197              Brooks, et al.
# 198                Yuan, et al.
# 199             Morales-Hidalgo
#
#                                                  Title  Year Published  \
# 0    Epidemiology of Autistic Conditions in Young C...            1966
# 1                     Epidemiology of infantile Autism            1970
# 2    A Prevalence investigation of Childhood Psychoses            1972
# 3    The prevalence of early childhood autism: comp...            1976
# 4    Severe impairments of social interaction and a...            1979
# ..                                                 ...             ...
# 195  School-Based Autism Rates by State: An Analysi...            2020
# ...

# %%
type(austism_prevalence_studies)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_size = autism_prevalence_studies['Sample Size']

# %%
year_published = autism_prevalence_studies['Year Published']

# %%
plt.plot(sample_size, year_published, 'o')

# %%
plt.figure(figsize = (12, 6)) 
plt.(sample_size, year_published)
plt.xlabel('Sample Size')#x and y label is character string and must have Quotations
plt.ylabel('Year Published')
plt.title('Scatterplot of Sales vs. Quantity')
plt.show()
